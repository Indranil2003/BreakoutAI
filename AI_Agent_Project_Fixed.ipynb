# %% [markdown]
# # BreakoutAI Assessment: AI Agent Project
# This notebook implements an AI agent capable of:
# - Reading datasets from CSV or Google Sheets.
# - Performing web searches for entities in the dataset.
# - Extracting information using a language model.
# - Displaying results in a Streamlit dashboard with options to download.
#
# ## Features
# - File Upload and Google Sheets Integration.
# - Dynamic Query Input.
# - Web Search Automation.
# - LLM Integration for Information Extraction.
# - Results Display and CSV Export.

# %%
# Install required libraries
# !pip install streamlit pandas google-api-python-client openai serpapi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in c:\users\indra\appdata\roaming\python\python312\site-packages (1.40.1)
# Requirement already satisfied: pandas in c:\users\indra\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: google-api-python-client in c:\users\indra\appdata\roaming\python\python312\site-packages (2.153.0)
# Requirement already satisfied: openai in c:\users\indra\appdata\roaming\python\python312\site-packages (1.54.4)
# Requirement already satisfied: serpapi in c:\users\indra\appdata\roaming\python\python312\site-packages (0.1.5)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: packaging<25,>=20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.28.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (18.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (2.36.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (2.23.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (4.67.0)
# Requirement already satisfied: jinja2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (1.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\indra\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: colorama in c:\users\indra\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.4)
# Requirement already satisfied: certifi in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)

# %%
pip install --upgrade google-search-results
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-search-results in c:\users\indra\appdata\roaming\python\python312\site-packages (2.4.2)
# Requirement already satisfied: requests in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests->google-search-results) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests->google-search-results) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests->google-search-results) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\indra\appdata\roaming\python\python312\site-packages (1.0.1)

# %%
# Import necessary modules
import streamlit as st
import pandas as pd
import openai
from googleapiclient.discovery import build
from serpapi import GoogleSearch
import os

# Set API keys as environment variables or load from a `.env` file
openai.api_key = os.getenv("OPENAI_API_KEY")
SERP_API_KEY = os.getenv("SERP_API_KEY")

# %%
# Define functions for data processing, search, and LLM interaction

def process_csv_file(file):
    """Process the uploaded CSV file."""
    data = pd.read_csv(file)
    return data

def search_web(entity, query_template):
    """Perform web search using SerpAPI."""
    search_query = query_template.replace("{entity}", entity)
    params = {
        "q": search_query,
        "api_key": SERP_API_KEY,
    }
    search = GoogleSearch(params)
    results = search.get("organic_results", [])
    return results

def extract_information(search_results, prompt_template):
    """Extract information from web search results using LLM."""
    prompt = prompt_template + "\n" + "\n".join(
        [result['snippet'] for result in search_results if 'snippet' in result]
    )
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100
    )
    return response["choices"][0]["text"].strip()

# %%
# Streamlit Dashboard Implementation

st.title("AI Data Extraction Agent")

# File upload
uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])
if uploaded_file:
    data = process_csv_file(uploaded_file)
    st.write("## Uploaded Data Preview")
    st.dataframe(data.head())
    
    # Query input
    query_template = st.text_input("Enter query template (use {entity} for placeholders)", "Get the email address of {entity}")
    prompt_template = st.text_area("Enter LLM prompt template", "Extract the email address from the following results:")

    # Process data
    if st.button("Process Data"):
        results = []
        for entity in data.iloc[:, 0]:
            search_results = search_web(entity, query_template)
            extracted_info = extract_information(search_results, prompt_template)
            results.append({"Entity": entity, "Extracted Info": extracted_info})
        
        # Display results
        results_df = pd.DataFrame(results)
        st.write("## Extraction Results")
        st.dataframe(results_df)
        
        # Download results
        csv = results_df.to_csv(index=False).encode('utf-8')
        st.download_button("Download Results", csv, "results.csv", "text/csv")
# Out:
# 2024-11-18 22:46:47.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 22:46:47.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Install required libraries
# !pip install streamlit pandas google-api-python-client openai serpapi python-dotenv

# Import necessary modules
import streamlit as st
import pandas as pd
import openai
from googleapiclient.discovery import build
from serpapi import GoogleSearch
import os
from dotenv import load_dotenv  # Import dotenv for loading .env file

# Load .env file
load_dotenv()

# Set API keys from the .env file
openai.api_key = os.getenv("OPENAI_API_KEY")
SERP_API_KEY = os.getenv("SERP_API_KEY")

# Define functions for data processing, search, and LLM interaction

def process_csv_file(file):
    """Process the uploaded CSV file."""
    data = pd.read_csv(file)
    return data

def search_web(entity, query_template):
    """Perform web search using SerpAPI."""
    search_query = query_template.replace("{entity}", entity)
    params = {
        "q": search_query,
        "api_key": SERP_API_KEY,
    }
    search = GoogleSearch(params)
    results = search.get("organic_results", [])
    return results

def extract_information(search_results, prompt_template):
    """Extract information from web search results using LLM."""
    prompt = prompt_template + "\n" + "\n".join(
        [result['snippet'] for result in search_results if 'snippet' in result]
    )
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100
    )
    return response["choices"][0]["text"].strip()

# Streamlit Dashboard Implementation

st.title("AI Data Extraction Agent")

# File upload
uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])
if uploaded_file:
    data = process_csv_file(uploaded_file)
    st.write("## Uploaded Data Preview")
    st.dataframe(data.head())
    
    # Query input
    query_template = st.text_input("Enter query template (use {entity} for placeholders)", "Get the email address of {entity}")
    prompt_template = st.text_area("Enter LLM prompt template", "Extract the email address from the following results:")

    # Process data
    if st.button("Process Data"):
        results = []
        for entity in data.iloc[:, 0]:
            search_results = search_web(entity, query_template)
            extracted_info = extract_information(search_results, prompt_template)
            results.append({"Entity": entity, "Extracted Info": extracted_info})
        
        # Display results
        results_df = pd.DataFrame(results)
        st.write("## Extraction Results")
        st.dataframe(results_df)
        
        # Download results
        csv = results_df.to_csv(index=False).encode('utf-8')
        st.download_button("Download Results", csv, "results.csv", "text/csv")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in c:\users\indra\appdata\roaming\python\python312\site-packages (1.40.1)
# Requirement already satisfied: pandas in c:\users\indra\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: google-api-python-client in c:\users\indra\appdata\roaming\python\python312\site-packages (2.153.0)
# Requirement already satisfied: openai in c:\users\indra\appdata\roaming\python\python312\site-packages (1.54.4)
# Requirement already satisfied: serpapi in c:\users\indra\appdata\roaming\python\python312\site-packages (0.1.5)
# Requirement already satisfied: python-dotenv in c:\users\indra\appdata\roaming\python\python312\site-packages (1.0.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: packaging<25,>=20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (5.28.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (18.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (2.36.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (2.23.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from openai) (4.67.0)
# Requirement already satisfied: jinja2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (1.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\indra\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: colorama in c:\users\indra\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.4)
# Requirement already satisfied: certifi in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\indra\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\indra\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\indra\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\indra\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# 2024-11-18 23:27:38.126 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.705
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\indra\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-18 23:27:38.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-18 23:27:38.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
